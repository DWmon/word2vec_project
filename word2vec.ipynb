# %%
from konlpy.tag import Kkma, Twitter


Twitter().pos("오버워치")  # [('오버', 'Noun'), ('워치', 'Noun')]
# Out:
# [('오버', 'Noun'), ('워치', 'Noun')]

# %%
import nltk

# %%
from konlpy.corpus import kobill

# %%
files_ko=kobill.fileids()

# %%
doc_ko=kobill.open('1809890.txt').read()

# %%
from konlpy.tag import Twitter

# %%
twitter = Twitter()

# %%
tokens_ko=twitter.morphs(doc_ko)

# %%
len(tokens_ko)
# Out:
# 1707

# %%
import nltk

# %%
ko=nltk.Text(tokens_ko, name='news')

# %%
print(len(ko.tokens))
# Out:
# 1707

# %%
ko.tokens
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '(',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  ')',
#  '의',
#  '안',
#  '번',
#  '호',
#  '9890',
#  '발의',
#  '연월일',
#  ':',
#  '2010',
#  '.',
#  '11',
#  '.',
#  '12',
#  '.',
#  '발',
#  '의',
#  '자',
#  ':',
#  '정의화',
#  '․',
#  '이명수',
#  '․',
#  '김을동',
#  '이사철',
#  '․',
#  '여상규',
#  '․',
#  '안규백',
#  '황영철',
#  '․',
#  '박영아',
#  '․',
#  '김정훈',
#  '김학송',
#  '의원',
#  '(',
#  '10',
#  '인',
#  ')',
#  '제안',
#  '이유',
#  '및',
#  '주요',
#  '내용',
#  '초등학교',
#  '저학년',
#  '의',
#  '경우',
#  '에도',
#  '부모',
#  '의',
#  '따뜻한',
#  '사랑',
#  '과',
#  '보살핌',
#  '이',
#  '필요',
#  '한',
#  '나이',
#  '이나',
#  ',',
#  '현재',
#  '공무원',
#  '이',
#  '자녀',
#  '를',
#  '양육',
#  '하기',
#  '위하여',
#  '육아휴직',
#  '을',
#  '할',
#  '수',
#  '있는',
#  '자녀',
#  '의',
#  '나이',
#  '는',
#  '만',
#  '6',
#  '세',
#  '이하',
#  '로',
#  '되어',
#  '있어',
#  '초등학교',
#  '저학년',
#  '인',
#  '자녀',
#  '를',
#  '돌보기',
#  '위해서',
#  '는',
#  '해당',
#  '부모님',
#  '은',
#  '일자리',
#  '를',
#  '그만',
#  '두어',
#  '야',
# ...

# %%
print(len(set(ko.tokens)))
# Out:
# 476

# %%
ko.vocab()
# Out:
# FreqDist({'%': 10,
#           '(': 27,
#           ')': 26,
#           ').': 1,
#           '+': 3,
#           ',': 26,
#           '-': 21,
#           '--------': 1,
#           '----------': 1,
#           '-------------------------': 1,
#           '---------------------------': 2,
#           '----------------------------': 4,
#           '--------------.': 1,
#           '-------------.---------------': 1,
#           '.': 61,
#           '/': 1,
#           '0': 5,
#           '02': 1,
#           '056': 1,
#           '1': 13,
#           '10': 6,
#           '11': 2,
#           '12': 1,
#           '145': 1,
#           '184': 1,
#           '185': 1,
#           '19': 1,
#           '2': 11,
#           '20': 1,
#           '200': 2,
#           '2007': 3,
#           '2008': 1,
#           '2009': 1,
#           '2010': 3,
#           '2011': 6,
#           '21': 2,
#           '29': 1,
#           '291': 1,
#           '3': 8,
#           '30': 1,
# ...

# %%
ko.plot(10)

# %%
ko.count('개정')
# Out:
# 8

# %%
from nltk.corpus import movie_reviews
sentences = [list(s) for s in movie_reviews.sents()]

# %%
sentences[-1]
# Out:
# ['nevertheless',
#  ',',
#  'i',
#  'look',
#  'forward',
#  'to',
#  'niccol',
#  "'",
#  's',
#  'next',
#  'film',
#  ',',
#  'whatever',
#  'it',
#  'may',
#  'be',
#  '.']

# %%
from gensim.models.word2vec import Word2Vec
# Out:
# C:\Users\DW\Anaconda3\envs\tensorflow\lib\site-packages\gensim-3.4.0-py3.5-win-amd64.egg\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %time
# Out:
# Wall time: 0 ns

# %%
# %%time
model=Word2Vec(sentences)
# Out:
# Wall time: 7.26 s

# %%
model.init_sims(replace=True)

# %%
model.wv.similarity('actor', 'actress')
# Out:
# 0.8597831950062673

# %%
model.wv.most_similar("villain")
# Out:
# [('rainmaker', 0.8266414403915405),
#  ('stalked', 0.7767784595489502),
#  ('bard', 0.7757800817489624),
#  ('feather', 0.7722179889678955),
#  ('celebrity', 0.7717260122299194),
#  ('doctor', 0.7665365934371948),
#  ('griffiths', 0.7605847120285034),
#  ('charming', 0.7580193281173706),
#  ('commoner', 0.7557873725891113),
#  ('lair', 0.7556633949279785)]

# %%
model.wv.most_similar(positive=['actor', 'she'], negative='actress', topn=1)
# Out:
# [('he', 0.293598473072052)]

# %%
import codecs

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets('computer')
# Out:
# [Synset('computer.n.01'), Synset('calculator.n.01')]

# %%
wn.synset('computer.n.01').definition()
# Out:
# 'a machine for performing calculations automatically'

# %%
wn.synsets('pertainyms')
# Out:
# [Synset('pertainym.n.01')]

# %%
documents = [["나는", "python", "이", "좋다"],
            ["나는", "R", "이", "좋다"]]

# %%
def read_data(filename):
    with open(filename,'r') as f:
        data=[line.split('/t') for line in f.read().splitlines()]
        data=data[1:]
    return data

# %%
train_data = read_data('ratings_train.txt')
test_data = read_data('ratings_test.txt')

# %%
print(len(test_data))
print(len(test_data[0]))
# Out:
# 50000
# 1

# %%
from konlpy.tag import Twitter
pos_tagger = Twitter()

# %%
def tokenize(doc):
    return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)]

# %%
train_docs = [(tokenize(row[0], row[1]) for row in train_data]
test_docs = [(tokenize(row[0]), row[1]) for row in test_data]
# Out:
#   File "<ipython-input-140-ed29e2b57d81>", line 1
#     train_docs = [(tokenize(row[0], row[1]) for row in train_data]
#                                                                  ^
# SyntaxError: invalid syntax

# %%
tokens = [t for d in train_docs for t in d[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-14ac857b8357> in <module>()
# ----> 1 tokens = [t for d in train_docs for t in d[0]]
#
# NameError: name 'train_docs' is not defined

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim import corpora, models, similarities

corpus = [[(0, 1.0), (1, 1.0), (2, 1.0)],
          [(2, 1.0), (3, 1.0), (4, 1.0), (5, 1.0), (6, 1.0), (8, 1.0)],
          [(1, 1.0), (3, 1.0), (4, 1.0), (7, 1.0)],
          [(0, 1.0), (4, 2.0), (7, 1.0)],
          [(3, 1.0), (5, 1.0), (6, 1.0)],
          [(9, 1.0)],
          [(9, 1.0), (10, 1.0)],
          [(9, 1.0), (10, 1.0), (11, 1.0)],
          [(8, 1.0), (10, 1.0), (11, 1.0)]]

# %%
tfidf = models.TfidfModel(corpus)
# Out:
# 2018-03-26 11:59:56,481 : INFO : collecting document frequencies
# 2018-03-26 11:59:56,483 : INFO : PROGRESS: processing document #0
# 2018-03-26 11:59:56,484 : INFO : calculating IDF weights for 9 documents and 11 features (28 matrix non-zeros)

# %%
vec = [(0, 1), (4, 1)]
print(tfidf[vec])
#[(0, 0.8075244), (4, 0.5898342)]
# Out:
# [(0, 0.8075244024440723), (4, 0.5898341626740045)]

# %%
from nltk.corpus import gutenberg   # Docs from project gutenberg.org
files_en = gutenberg.fileids()      # Get file ids
doc_en = gutenberg.open('austen-emma.txt').read()

# %%
#예제코드

# %%
from konlpy.corpus import kobill
docs_ko = [kobill.open(i).read() for i in kobill.fileids()]
docs_ko
# Out:
# ['지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n------------------------
# ...

# %%
from konlpy.tag import Twitter
t = Twitter()
pos = lambda d: ['/'.join(p) for p in t.pos(d)]
texts_ko = [pos(doc) for doc in docs_ko]

# %%
from gensim.models import word2vec
wv_model_ko = word2vec.Word2Vec(texts_ko)
#wv_model_ko.init_sims(replace=True)
#wv_model_ko.save('ko_word2vec.model')
# Out:
# 2018-03-29 02:23:04,152 : INFO : collecting all words and their counts
# 2018-03-29 02:23:04,154 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-03-29 02:23:04,160 : INFO : collected 1720 word types from a corpus of 18270 raw words and 10 sentences
# 2018-03-29 02:23:04,161 : INFO : Loading a fresh vocabulary
# 2018-03-29 02:23:04,167 : INFO : min_count=5 retains 627 unique words (36% of original 1720, drops 1093)
# 2018-03-29 02:23:04,169 : INFO : min_count=5 leaves 16067 word corpus (87% of original 18270, drops 2203)
# 2018-03-29 02:23:04,174 : INFO : deleting the raw counts dictionary of 1720 items
# 2018-03-29 02:23:04,176 : INFO : sample=0.001 downsamples 88 most-common words
# 2018-03-29 02:23:04,177 : INFO : downsampling leaves estimated 11657 word corpus (72.6% of prior 16067)
# 2018-03-29 02:23:04,182 : INFO : estimated required memory for 627 words and 100 dimensions: 815100 bytes
# 2018-03-29 02:23:04,183 : INFO : resetting layer weights
# ...

# %%
wv_model_ko.wv.most_similar(pos('정부'))
wv_model_ko.wv.most_similar(pos('초등학교'))
# Out:
# [('을/Josa', 0.9997769594192505),
#  ('의/Josa', 0.9997697472572327),
#  ('자녀/Noun', 0.9997648596763611),
#  ('는/Josa', 0.9997500777244568),
#  ('로/Josa', 0.9997462630271912),
#  ('에서/Josa', 0.9997453093528748),
#  ('또는/Adverb', 0.9997380971908569),
#  ('이/Noun', 0.9997309446334839),
#  ('이상/Noun', 0.9997298717498779),
#  ('에는/Josa', 0.9997264742851257)]

# %%
from gensim.corpora.wikicorpus import WikiCorpus
from gensim.models.word2vec import Word2Vec, LineSentence
from pprint import pprint
from copy import deepcopy
from multiprocessing import cpu_count
from smart_open import smart_open
# Out:
# C:\Users\DW\Anaconda3\envs\tensorflow\lib\site-packages\gensim-3.4.0-py3.5-win-amd64.egg\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
wget https://dumps.wikimedia.org/archive/2010/2010-11/enwiki/20101011/enwiki-20101011-pages-articles.xml.bz2
wget https://dumps.wikimedia.org/enwiki/20160820/enwiki-20160820-pages-articles.xml.bz2
# Out:
#   File "<ipython-input-4-9d9f6f87b000>", line 2
#     wget https://dumps.wikimedia.org/archive/2010/2010-11/enwiki/20101011/enwiki-20101011-pages-articles.xml.bz2
#              ^
# SyntaxError: invalid syntax

# %%
old, new = [WikiCorpus('enwiki-{}-pages-articles.xml.bz2'.format(ymd)) for ymd in ['20101011', '20160820']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-122f0f6edb87> in <module>()
# ----> 1 old, new = [WikiCorpus('enwiki-{}-pages-articles.xml.bz2'.format(ymd)) for ymd in ['20101011', '20160820']]
#
# <ipython-input-3-122f0f6edb87> in <listcomp>(.0)
# ----> 1 old, new = [WikiCorpus('enwiki-{}-pages-articles.xml.bz2'.format(ymd)) for ymd in ['20101011', '20160820']]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\gensim-3.4.0-py3.5-win-amd64.egg\gensim\corpora\wikicorpus.py in __init__(self, fname, processes, lemmatize, dictionary, filter_namespaces, tokenizer_func, article_min_tokens, token_min_len, token_max_len, lower)
#     550         self.token_max_len = token_max_len
#     551         self.lower = lower
# --> 552         self.dictionary = dictionary or Dictionary(self.get_texts())
#     553
#     554     def get_texts(self):
#
# ...

# %%
bb

# %%
from nltk.corpus import movie_reviews
sentences = [list(s) for s in movie_reviews.sents()]

# %%
sentences[0]
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'to',
#  'a',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'and',
#  'then',
#  'drive',
#  '.']

# %%
from gensim.models.word2vec import Word2Vec

# %%
# %%time
model = Word2Vec(sentences, size=100, window = 8, min_count=10, workers=4, iter=100)
# Out:
# Wall time: 1min 59s

# %%
model.init_sims(replace=True)

# %%
model.wv.most_similar('actor')
# Out:
# [('actress', 0.6599868535995483),
#  ('performance', 0.5339940190315247),
#  ('role', 0.4692545533180237),
#  ('performer', 0.4636976718902588),
#  ('actors', 0.45986706018447876),
#  ('oscar', 0.4490167796611786),
#  ('accomplishment', 0.44720393419265747),
#  ('amateur', 0.4313931465148926),
#  ('guy', 0.4171171486377716),
#  ('cast', 0.41439148783683777)]

# %%
model.similarity('he', 'she')
# Out:
# C:\Users\DW\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   if __name__ == '__main__':
# 0.8553155269087536

# %%
model.similarity('actor', 'she')
# Out:
# C:\Users\DW\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   if __name__ == '__main__':
# 0.2613913620533771

# %%
model.most_similar("villain")
# Out:
# C:\Users\DW\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('charming', 0.7767438888549805),
#  ('actress', 0.775795578956604),
#  ('landlady', 0.7715349197387695),
#  ('appealing', 0.7673214673995972),
#  ('rabbi', 0.7645660638809204),
#  ('bilal', 0.7608462572097778),
#  ('bimbo', 0.7600882649421692),
#  ('actor', 0.7558844685554504),
#  ('feather', 0.7475110292434692),
#  ('doe', 0.746601402759552)]

# %%
from konlpy.tag import Twitter

# %%
t=Twitter()
t.add_dictionary('아이오아이', 'Noun')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1bb4fee1ccf8> in <module>()
#       1 t=Twitter()
# ----> 2 t.add_dictionary('아이오아이', 'Noun')
#
# AttributeError: 'Twitter' object has no attribute 'add_dictionary'

# %%
t.pos('우리아이오아이는 이뻐요')
# Out:
# [('우리', 'Noun'),
#  ('아이오', 'Noun'),
#  ('아이', 'Noun'),
#  ('는', 'Josa'),
#  ('이뻐', 'Adjective'),
#  ('요', 'Eomi')]

# %%
from konlpy.tag import Twitter

twitter.add_dictionary('아이오아이', 'Noun')
#twitter.add_dictionary(['트와이스', 'tt'], 'Noun')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fe9fb1e307db> in <module>()
#       1 from konlpy.tag import Twitter
#       2
# ----> 3 twitter.add_dictionary('아이오아이', 'Noun')
#       4 #twitter.add_dictionary(['트와이스', 'tt'], 'Noun')
#
# NameError: name 'twitter' is not defined
